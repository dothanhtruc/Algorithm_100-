# %%
import numpy as np
from bokeh.plotting import figure, show, output_notebook

# %% [markdown]
# <h2>Algorithm</h2>

# %%
xs, ys, cs = [], [], []
for x in range(0,50):
    for y in range(0,50):
        up = np.random.randint(0,2)
        xs.append([x, x + .8])
        ys.append([y + .8 * (up>=.5), y + .8 * (up<.5)])
        
        col = np.random.randint(0, 4)
        cs.append({0:'white', 1:'red', 2:'green', 3:'blue'}[col])

# %% [markdown]
# <h2>Plot</h2>

# %%
output_notebook()
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
plot = figure(plot_width=800, plot_height=800)

plot.grid.visible = False
plot.xaxis.visible = False
plot.yaxis.visible = False

plot.multi_line(xs, ys, color=cs, line_width=6, line_alpha=.1, line_cap='round')
plot.multi_line(xs, ys, color='black')
show(plot)
# Out:
#   <div class="bk-root" id="4cf29847-3662-4710-b0b2-75bb0811475f" data-root-id="1124"></div>
